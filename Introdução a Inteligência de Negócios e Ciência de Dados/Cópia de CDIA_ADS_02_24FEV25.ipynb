# %% [markdown]
# # Listas

# %%
# Criando a lista
listadomercado = ['pão, queijo, sardinha, macarrão, salsinha, molho']

# %%
print(listadomercado)
# Out:
# ['pão, queijo, sardinha, macarrão, salsinha, molho']

# %%
print(listadomercado[0])
# Out:
# pão, queijo, sardinha, macarrão, salsinha, molho

# %%
type(listadomercado)
# Out:
# list

# %%
lista2 = [12, 100, 'Senac']

# %%
item1 = lista2[0]
item2 = lista2[1]
item3 = lista2[2]

# %%
print(item3, item1)
# Out:
# Senac 12

# %%
type(lista2)
# Out:
# list

# %%
type(lista2[2])
# Out:
# str

# %%
lista2[2] = 50

# %%
lista2
# Out:
# [12, 100, 50]

# %%
del lista2[2]

# %%
# Lista de listas ou listas aninhadas
listadelistas = [[1,2,3] , [4,5,6] , [7.0,8.0,9.0]]

# %%
listadelistas
# Out:
# [[1, 2, 3], [4, 5, 6], [7.0, 8.0, 9.0]]

# %%
listadelistas[0]
# Out:
# [1, 2, 3]

# %%
listadelistas[2][1]
# Out:
# 8.0

# %%
listadelistas[2] + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-14ab7bb6d43e> in <cell line: 0>()
# ----> 1 listadelistas[2] + 10
#
# TypeError: can only concatenate list (not "int") to list

# %%
listadelistas[2][1] + 10

# %%
listanova = listadelistas + lista2 + listadomercado

# %%
listanova

# %%
lista2 * 3

# %%
'abc' * 2

# %%
# operador in
print(100 in lista2)

# %%
len(listadomercado)

# %%
min(lista2)

# %%
max(lista2)

# %%
min(listadelistas)

# %%
listanova2 = ['victor','lucca','guilherme','4']

# %%
listanova2

# %%
min(listanova2)

# %%
listanova2.append('clayton')

# %%
listanova2

# %%
lista3 = [5,6,7]

# %%
new_list = []

# %%
for item in lista3:
  new_list.append(item)

# %%
new_list

# %%
cidades = ['Rio de Janeiro','Niterói','Duque de Caxias']

# %%
cidades.extend(['Petrópolis','Paracambi','Nova Iguaçú'])

# %%
cidades

# %%
cidades.insert(3,'Angra dos Reis')

# %%
cidades

# %%
cidades.remove('Angra dos Reis')

# %%
cidades

# %%
cidades.reverse()

# %%
cidades
# Out:
# ['Duque de Caxias',
#  'Niterói',
#  'Nova Iguaçú',
#  'Paracambi',
#  'Petrópolis',
#  'Rio de Janeiro']

# %%
cidades.sort()

# %%
cidades
# Out:
# ['Duque de Caxias',
#  'Niterói',
#  'Nova Iguaçú',
#  'Paracambi',
#  'Petrópolis',
#  'Rio de Janeiro']

# %%
cidades.sort(reverse=True)

# %%
cidades
# Out:
# ['Rio de Janeiro',
#  'Petrópolis',
#  'Paracambi',
#  'Nova Iguaçú',
#  'Niterói',
#  'Duque de Caxias']

# %% [markdown]
# # Dicionário

# %%
listadeestudantes = ['Maria',12,'João',14,'Jose',15]

# %%
listadeestudantes
# Out:
# ['Maria', 12, 'João', 14, 'Jose', 15]

# %%
dicionariodeestudantes = {'Maria':12, 'Joao':14, 'Jose':15}

# %%
dicionariodeestudantes
# Out:
# {'Maria': 12, 'Joao': 14, 'Jose': 15}

# %%
dicionariodeestudantes.clear()

# %%
dicionariodeestudantes
# Out:
# {}

# %%
dicionariodeestudantes
# Out:
# {'Maria': 12, 'Joao': 14, 'Jose': 15}

# %%
len(dicionariodeestudantes)
# Out:
# 3

# %%
dicionariodeestudantes.keys()
# Out:
# dict_keys(['Maria', 'Joao', 'Jose'])

# %%
dicionariodeestudantes.values()
# Out:
# dict_values([12, 14, 15])

# %%
dicionario2 = {'clayton':49}

# %%
dicionariodeestudantes.update(dicionario2)

# %%
dicionariodeestudantes
# Out:
# {'Maria': 12, 'Joao': 14, 'Jose': 15, 'clayton': 49}

# %%
dicionario3 = {1: ['Maria','Av. Brasil 100'], 1: ['Joao', 'Av. Beira Mar 100'], 2: ['Jose', 'Av Brasil 120']}

# %%
dicionario3
# Out:
# {1: ['Joao', 'Av. Beira Mar 100'], 2: ['Jose', 'Av Brasil 120']}

# %%
dicionario3[1]
# Out:
# ['Joao', 'Av. Beira Mar 100']
